# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#sample 1
elements = ['Bromine','Sodium', 'Antimony', 'Potassium','Rubidium', 'Cobalt',
           'Mercury', 'Cesium']

ppm = [1.4, 980.2, 2.57, 2588.97, 2.22, 0.043, 0.035, 0.21]
sys_unc = [0.45, 428.53, 0.62, 1325.27, 1.056, 0.022, 0.0043, 0.061]
stat_unc = [0.07, 5.66, 0.17, 98.93, 0.058, 0.0056, 0.0026, 0.016]
x = np.linspace(1,len(ppm),len(ppm))
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)

mpl_fig = plt.figure(figsize=(10,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3000, 1.5, 1000, 20, 0.3, 1, 0.01]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 1: Swai Basa Fillet from Vietnam')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 2
elements = ['Bromine','Sodium', 'Arsenic', 'Potassium','Mercury', 'Barium',
           'Antimony', 'Cesium', 'Rubidium', 'Selenium','Cobalt', 'Gold']

ppm = [4.15, 64.70, 1.45, 3780.58, 0.234, 10.48, 0.31, 0.212, 0.14, 1.63, 0.052, 0.00075]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [1.32, 28.48, 0.43, 1935.24, 0.029, 1.26, 0.08, 0.057, 0.068, 0.18, 0.027, 0.00014]
stat_unc = [0.12, 2.06, 0.14, 790.84, 0.031, 1.81, 0.07, 0.038, 0.014, 0.19, 0.0059, 0.00009]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)

mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3000, 3.5, 1000, 1, 14.3, 1.5, 0.01, 20, 0.58, 0.3, 0.0005]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 2: Hamachi Fillet from JAPAN')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 3
elements = ['Bromine','Sodium', 'Cobalt', 'Selenium','Mercury', 'Rubidium',
           'Antimony', 'Cesium', 'Potassium', 'Arsenic']

ppm = [2.16, 69.16, 0.274, 0.923, 0.024, 0.15, 0.0277, 0.032, 2650.95, 0.62]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [0.7, 30.68, 0.14, 0.087, 0.003, 0.07, 0.01, 0.0094, 1357, 0.19]
stat_unc = [0.07, 2.54, 0.031, 0.072, 0.0022, 0.014, 0.01, 0.0048, 95.49, 0.092]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)

mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3000, 0.3, 0.58, 1, 20, 1.5, 0.01, 1000, 3.5]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Isotope ppm of Sample 3: Cardinal snapper from MEXICO')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 4
elements = ['Bromine','Potassium', 'Cobalt', 'Arsenic','Sodium', 'Barium',
           'Selenium', 'Cesium', 'Mercury', 'Rubidium']

ppm = [5.5, 3322.37, 1.52, 0.7, 164.3, 25.22, 2.10, 0.25, 0.22, 0.144]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [1.8, 1700.69, 0.77, 0.21, 70.72, 2.03, 0.2, 0.1, 0.027, 0.069]
stat_unc = [0.13, 88.56, 0.11, 0.081, 7.94, 5.3, 0.25, 0.091, 0.0065, 0.014]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)

mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 1000, 0.3, 3.5, 3000, 14.3, 0.58, 0.01, 1, 20]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 4: Shortraker steak from CANADA')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 5
elements = ['Bromine','Potassium','Cobalt', 'Arsenic', 'Sodium',
           'Selenium','Rubidium', 'Cesium', 'Iron']

ppm = [4.61, 3556.56, 0.885, 0.83, 143.56, 1.77, 0.25, 0.06, 3.58]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [1.45, 1820.56, 0.45, 0.23, 62.91, 0.17, 0.12, 0.019, 1.83]
stat_unc = [0.24, 144.19, 0.087, 0.08, 1.24, 0.13, 0.020, 0.006, 0.55]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 1000, 0.3, 3.5, 3000, 0.58, 20, 0.01, 13.5]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 5: Yellow tail snapper from Brazil')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 6
elements = ['Sodium','Potassium', 'Bromine','Selenium', 'Arsenic',
           'Cesium', 'Rubidium', 'Iron','Cobalt']

ppm = [510.92, 5369.57, 2.19, 0.79, 0.64, 0.25, 1.82, 6.48, 0.05]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [204.54, 2748.11, 0.24, 0.07, 0.19, 0.073, 0.87, 3.12, 0.026]
stat_unc = [154.81, 174.78, 0.21, 0.088, 0.09, 0.038, 0.092, 0.73, 0.0058]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)

mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [3000, 1000, 13, 0.58, 3.5, 0.01, 20, 13.5, 0.3]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 6: Tilapia from TAIWAN')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 7
elements = ['Sodium', 'Potassium','Selenium', 'Rubidium', 'Cobalt',
           'Mercury', 'Gold', 'Bromine']

ppm = [152.35, 2436.11, 0.78, 0.78, 0.1, 0.09, 0.00086, 1.46]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [66.67, 1247, 0.077, 0.37, 0.05, 0.011, 0.00016, 0.48]
stat_unc = [1.03, 96.54, 0.06, 0.037, 0.0087, 0.0043, 0.000067, 0.06]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)

mpl_fig = plt.figure(figsize=(10,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [3000, 1000, 0.58, 20, 0.3, 1, 0.0005, 13]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 7: Grass carp steak from TAIWAN')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 8
elements = ['Bromine','Arsenic', 'Potassium','Sodium', 'Cobalt',
           'Selenium','Mercury','Rubidium','Cesium']

ppm = [3.33, 2.73, 2360.73, 9384.64, 0.22, 0.39, 0.064, 0.114, 0.033]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [1.034, 0.74, 1208.43, 3168.57, 0.11, 0.04, 0.008, 0.054, 0.011]
stat_unc = [0.02, 0.56, 163.37, 3237, 0.032, 0.024, 0.0048, 0.011, 0.0045]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3.5, 1000, 3000, 0.3, 0.58, 1, 20, 0.01]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 8: Grass carp steak from TAIWAN')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 9
elements = ['Bromine','Arsenic', 'Potassium','Sodium', 'Gold', 'Selenium',
           'Mercury', 'Scandium', 'Cesium','Cobalt', 'Rubidium']

ppm = [7.77, 7.04, 2006.06, 207.54, 0.0025, 1.93, 0.09, 0.00055, 0.085, 0.03, 0.125]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [2.39, 2.07, 1026.88, 91.25, 0.00046, 0.18, 0.011, 0.00023, 0.027, 0.013, 0.059]
stat_unc = [0.47, 0.36, 194.5, 2.25, 0.00029, 0.14, 0.003, 0.000073, 0.0064, 0.0029, 0.011]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3.5, 1000, 3000, 0.0005, 0.58, 1, 0, 0.01, 0.3, 20]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 9: Chilean sea bass from KOREA')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 10
elements = ['Bromine','Sodium', 'Arsenic', 'Potassium','Antimony', 'Barium',
           'Cobalt', 'Mercury', 'Scandium', 'Cesium','Rubidium', 'Selenium']

ppm = [2.92, 50.48, 0.56, 2164.19, 0.064, 51.01, 0.17, 0.0085, 0.00027, 0.091, 0.24, 0.34]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [0.96, 22.26, 0.17, 1107.83, 0.017, 7.22, 0.085, 0.001, 0.00011, 0.027, 0.11, 0.033]
stat_unc = [0.09, 1.0, 0.095, 181.28, 0.0084, 7.23, 0.018, 0.0011, 0.000061, 0.0093, 0.019, 0.021]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3000, 3.5, 1000, 1.5, 14.3, 0.3, 1, 0, 0.01, 20,0.58]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 10: Wild isle salmon from SCOTLAND')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 11
elements = ['Bromine','Sodium', 'Arsenic', 'Potassium','Cobalt', 'Mercury',
           'Selenium', 'Iron', 'Rubidium']

ppm = [13.22, 110.81, 1.16, 1736.26, 0.19, 0.066, 1.78, 7.88, 0.203]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [6.54, 48.87, 0.34, 888.78, 0.098, 0.0097, 0.16, 3.27, 0.11]
stat_unc = [2.22, 1.07, 0.1, 112.71, 0.012, 0.0038, 0.08, 0.92, 0.025]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [13, 3000, 3.5, 1000, 0.3, 1, 0.58, 13.5, 20]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 11: Mackarel from INDIA')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 12
elements = ['Potassium','Sodium', 'Bromine', 'Arsenic','Cobalt', 'Mercury',
           'Antimony', 'Rubidium', 'Cesium','Selenium']

ppm = [1652.5, 85.33, 3.38, 2.14, 0.127, 0.048, 0.5736, 0.084, 0.02, 0.56]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [845.9, 37.58, 1.06, 0.64, 0.064, 0.006, 0.25, 0.04, 0.0057, 0.053]
stat_unc = [185.65, 1.83, 0.13, 0.22, 0.017, 0.0029, 0.25, 0.013, 0.0029, 0.029]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [1000, 3000, 13, 3.5, 0.3, 1, 1.5, 20, 0.01, 0.58]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 12: Norwegian basa from NORWAY')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 13
elements = ['Potassium','Cobalt', 'Bromine', 'Arsenic','Cesium', 'Sodium',
           'Rubidium', 'Selenium','Mercury']

ppm = [2103.34, 0.244, 3.68, 1.65, 0.11, 95.74, 0.25, 0.42, 0.02]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [1076.68, 0.12, 1.16, 0.49, 0.035, 40.13, 0.12, 0.041, 0.0023]
stat_unc = [322.2, 0.043, 0.14, 0.21, 0.024, 2.6, 0.024, 0.031, 0.002]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [1000, 0.3, 13, 3.5, 0.01, 3000, 20, 0.58, 1]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 13: Golden pompano from CHINA')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 14
elements = ['Sodium','Bromine', 'Potassium', 'Arsenic','Rubidium','Cobalt',
           'Scandium', 'Cesium', 'Mercury', 'Selenium']

ppm = [91.89, 23.19, 1930.47, 0.64, 0.22, 0.08, 0.001, 0.22, 0.15, 0.96]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [40.3, 6.97, 834.62, 0.19, 0.1, 0.04, 0.0007, 0.067, 0.018, 0.092]
stat_unc = [1.93, 3.75, 123.31, 0.099, 0.027, 0.012, 0.00034, 0.025, 0.0079, 0.057]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [3000, 13, 1000, 3.5, 20, 0.3, 0, 0.01, 1, 0.58]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 14: Chilean sea bass from the ARTIC')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 15
elements = ['Sodium','Potassium', 'Cobalt','Selenium','Strontium','Scandium',
           'Arsenic', 'Mercury', 'Rubidium', 'Iron', 'Bromine']

ppm = [303.97, 1856.51, 1.45, 0.72, 34.34, 0.0084, 1.19, 0.047, 0.31, 15.57, 61.80]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [133.68, 950.33, 0.74, 0.066, 12.23, 0.00037, 0.37, 0.0058, 0.15, 7.78, 19.83]
stat_unc = [3.37, 136.6, 0.038, 0.045, 1.79, 0.00047, 0.14, 0.0022, 0.019, 0.83, 3.45]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [3000, 1000, 0.3, 0.58, 8, 0, 3.5, 1, 20, 13.5, 13]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 15: HD shrimp from VENEZUELA')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()

# %%
#sample 16
elements = ['Potassium', 'Bromine','Sodium','Mercury',
           'Cobalt', 'Selenium', 'Cesium']

ppm = [1473.66, 5.83, 176.69, 0.75, 0.166, 1.51, 0.09]
x = np.linspace(1,len(ppm),len(ppm))
sys_unc = [754.35, 1.92, 80.61, 0.093, 0.084, 0.15, 0.024]
stat_unc = [98.09, 0.21, 4.79, 0.023, 0.022, 0.10, 0.013]
tot_unc = []
for i in x:
    val = (sys_unc[int(i)-1]**2+stat_unc[int(i)-1]**2)**0.5
    tot_unc.append(val)
    
mpl_fig = plt.figure(figsize=(12,5))
ax = mpl_fig.add_subplot(111)
width = 0.5
p1 = ax.bar(x, ppm, width, color='powderblue', label='Element')

#reference values (based on averages)
ppm2 = [1000, 13, 3000, 1, 0.3, 0.58, 0.01]
#reference graph
p2 = ax.bar(x, ppm2, width=0.35, color='lightsalmon', edgecolor='red', alpha=0.3, label='Reference')
p3 = plt.errorbar(x, ppm, yerr=tot_unc, fmt='.', ecolor='steelblue', capthick=1, capsize=2)

plt.xlabel('Element')
plt.ylabel('Concentration in ppm')
plt.title('Element ppm of Sample 16: Pink grouper steak from MEXICO')
plt.legend()
plt.xticks(x, elements)
ax.set_yscale('log')
plt.show()
